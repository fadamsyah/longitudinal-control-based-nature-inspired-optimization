# %% [markdown]
# # INTRODUCTION: MODEL 1

# %% [markdown]
# **Model** that is used to map steady-state speed to throttle is given as follows:
#
# $\displaystyle{ \hat{u}_s = \beta_1 \left(1 - e^{\beta_2 (v_s - \beta_3)} \right), \; \hat{u}_s \geq 0 }$
#
# where $u_s$ is throttle, $v_s$ is steady-state speed given constant input, and $\beta_1, \beta_2, \beta_3 \in \Re$
#
# The **optimization formulation** is given by:
#
# $ \displaystyle{
# J = \frac{1}{2m} \sum_{i=1}^m \left[u_s - \hat{u}_s \right]^2
# } $
#
# In this section, **flower pollination algorithm** (FPA) will be used to minimize the cost function $J$. The constraint is described as follows:
#
# $ \displaystyle{
#     \beta_1, \beta_3 \geq 0
# } $
#
# $\displaystyle{
# \beta_2 \leq 0
# }$

# %% [markdown]
# # IMPORT LIBRARY AND DATA

# %%
import numpy as np
import numba as nb
import math
import matplotlib.pyplot as plt
import pandas as pd
import time
from numba import njit, prange
from os import listdir
from os.path import isfile, join

# %matplotlib inline
plt.style.use(['science','ieee'])

# %%
df = pd.read_csv('../steady_state_response.csv')
v = np.array(df.ssv)
u = np.array(df.u)


plt.figure()
plt.scatter(v, u)
plt.xlabel('Steady state speed (m/s)')
plt.ylabel('Throttle')
plt.show()

# %% [markdown]
# # MAKE FUNCTION

# %% [markdown]
# ## Generate population

# %%
def generate_population(num, dim, rng):
    """
    Generate population:
        Input:
            num: number of population (integer)
            dim: number of parameters (integer)
            rng: range number used in initialization (list or numpy array)
        Output:
            pop: initial position of the population (numpy array)
    """
    pop = np.zeros((num,dim))
    for i in range(dim):
        lim = rng[i]
        pop[:, i] = np.random.uniform(lim[0], lim[1], size=num)
    return pop

# %% [markdown]
# ## Constraint

# %%
@njit
def admissible(param):
    b1, b2, b3 = param
    if b1 < 0. or b2 > 0. or b3 < 0.:
        return False
    else:
        return True
_ = admissible(np.random.randn(3))

# %% [markdown]
# ## Forward propagation

# %%
@njit
def forward_propagation(u, param):
    b1, b2, b3 = param
    
    out = b1 * (1 - np.exp(b2*(u))) + b3
    out = np.fmax(out, 0.)
    
    # When the vehicle is not moving
    out[u <= 1e-2] = 0.
    
    return out

_ = forward_propagation(np.array([0.0, 0.1]), np.ones(3)*0.5)

# %% [markdown]
# ## Cost and metric

# %%
@njit
def cost(u, v, param):
    error = v - forward_propagation(u, param)
    cost = np.mean(error**2)
    return cost
_ = cost(v, u, np.ones(3)*0.5)

# %%
@njit
def calculate_total_cost(param):    
    if admissible(param):
        loss = cost(v, u, param)
    else:
        loss = np.Inf
    return loss
_ = calculate_total_cost(np.ones(3)*0.5)

# %%
@njit(parallel=True)
def population_cost(population):
    length = population.shape[0]
    losses = np.zeros(length)
    for ii in prange(length):
        losses[ii] = calculate_total_cost(population[ii])
    return losses
_ = population_cost(np.random.randn(2,3))

# %% [markdown]
# ## APSO

# %%
@njit
def apso(population, loss_population, global_, global_loss, alpha0, beta, gamma, n_itr):
    num = population.shape[0]
    dim = population.shape[1]
    
    # Initial conditions
    ppos_vector = np.copy(population)
    pbest_pos = np.copy(ppos_vector)
    pfit_value = np.copy(loss_population)
    gbest_pos = np.copy(global_)
    gfit_value = global_loss
    
    for i in range(num):
        # Update the alpha value
        alpha = alpha0*gamma**n_itr
            
        # Update the velocity and position vector
        ppos_vector[i] = (1-beta)*ppos_vector[i] + alpha*np.random.normal(0,1) + beta*gbest_pos
        
        cost_func = calculate_total_cost(ppos_vector[i])
        
        # Update each values using the cost functions
        if(pfit_value[i] > cost_func):
            pfit_value[i] = cost_func
            pbest_pos[i] = np.copy(ppos_vector[i])
                
        if(gfit_value > cost_func):
            gfit_value = cost_func
            gbest_pos = np.copy(ppos_vector[i])
    
    return pbest_pos, pfit_value, gbest_pos, gfit_value
    
xx1 = np.ones((2, 3))*1.0
xx2 = np.ones(2)
xx3 = np.ones(3)*0.5
_ = apso(xx1, xx2, xx3, 100.0, 0.8, 1.5, 0.1, 5)

# %% [markdown]
# # SIMULATION

# %%
num = 25
n_sim = 50
n_itr = 5000

r_b1 = [0.,  2.]
r_b2 = [0., -2.]
r_b3 = [0.,  2.]

rng = [r_b1, r_b2, r_b3]
dim = len(rng)

alpha0 = 0.6
beta = 0.5
gamma = 0.8

param_history = np.zeros((n_sim, dim))
loss_history = np.ones(n_sim)*np.Inf

the_best_param_history = np.zeros((n_itr, dim))
the_best_loss_history = np.zeros(n_itr)

for j in range(n_sim):
    population = generate_population(num, dim, rng)
    global_ = None
    global_loss_ = np.Inf
    
    loss_population = population_cost(population)
    loss_population[np.isnan(loss_population)] = np.Inf
    min_idx = np.argmin(loss_population)
    min_loss = loss_population[min_idx]
    if global_loss_ > min_loss:
        global_loss_ = min_loss
        global_ = np.copy(population[min_idx, :])
        
    global_history = np.empty((n_itr, dim))
    global_history[0] = global_
    global_loss_history = np.empty(n_itr)
    global_loss_history[0] = global_loss_
    for i in range(1, n_itr):
        # Particle Swarm Optimization
        population, loss_population, global_, global_loss_ = apso(population, loss_population, global_, global_loss_, alpha0, beta, gamma, j+1)
        
        global_history[i] = global_
        global_loss_history[i] = global_loss_
    
    if np.min(loss_history) > global_loss_history[-1]:
        the_best_loss_history = np.copy(global_loss_history)
        the_best_param_history = np.copy(global_history)
        
    param_history[j] = np.copy(global_history[-1])
    loss_history[j] = np.copy(global_loss_history[-1])
    
    print('simulation: {} || global loss: {:.10f} || the best loss: {:.10f}'.format(j, global_loss_history[-1], the_best_loss_history[-1]))
# Out:
# simulation: 0 || global loss: 0.0275131253 || the best loss: 0.0275131253
# simulation: 1 || global loss: 0.0239172946 || the best loss: 0.0239172946
# simulation: 2 || global loss: 0.0325362054 || the best loss: 0.0239172946
# simulation: 3 || global loss: 0.0187028092 || the best loss: 0.0187028092
# simulation: 4 || global loss: 0.0228003875 || the best loss: 0.0187028092
# simulation: 5 || global loss: 0.0277796518 || the best loss: 0.0187028092
# simulation: 6 || global loss: 0.0294590161 || the best loss: 0.0187028092
# simulation: 7 || global loss: 0.0321486191 || the best loss: 0.0187028092
# simulation: 8 || global loss: 0.0452781326 || the best loss: 0.0187028092
# simulation: 9 || global loss: 0.0236078982 || the best loss: 0.0187028092
# simulation: 10 || global loss: 0.0050870073 || the best loss: 0.0050870073
# simulation: 11 || global loss: 0.0279154664 || the best loss: 0.0050870073
# simulation: 12 || global loss: 0.0087671819 || the best loss: 0.0050870073
# simulation: 13 || global loss: 0.0334641429 || the best loss: 0.0050870073
# simulation: 14 || global loss: 0.0364585848 || the best loss: 0.0050870073
# simulation: 15 || global loss: 0.0410878952 || the best loss: 0.0050870073
# simulation: 16 || global loss: 0.0304527806 || the best loss: 0.0050870073
# simulation: 17 || global loss: 0.0447100774 || the best loss: 0.0050870073
# simulation: 18 || global loss: 0.0050979061 || the best loss: 0.0050870073
# simulation: 19 || global loss: 0.0361253694 || the best loss: 0.0050870073
# simulation: 20 || global loss: 0.0120239412 || the best loss: 0.0050870073
# simulation: 21 || global loss: 0.0054042130 || the best loss: 0.0050870073
# simulation: 22 || global loss: 0.0148391717 || the best loss: 0.0050870073
# simulation: 23 || global loss: 0.0143784146 || the best loss: 0.0050870073
# simulation: 24 || global loss: 0.0402644402 || the best loss: 0.0050870073
# simulation: 25 || global loss: 0.0295082706 || the best loss: 0.0050870073
# simulation: 26 || global loss: 0.0583594021 || the best loss: 0.0050870073
# simulation: 27 || global loss: 0.0144940831 || the best loss: 0.0050870073
# simulation: 28 || global loss: 0.0132890349 || the best loss: 0.0050870073
# simulation: 29 || global loss: 0.0453329994 || the best loss: 0.0050870073
# simulation: 30 || global loss: 0.0156023249 || the best loss: 0.0050870073
# simulation: 31 || global loss: 0.0276466205 || the best loss: 0.0050870073
# simulation: 32 || global loss: 0.0303810492 || the best loss: 0.0050870073
# simulation: 33 || global loss: 0.0275231378 || the best loss: 0.0050870073
# simulation: 34 || global loss: 0.0320715233 || the best loss: 0.0050870073
# simulation: 35 || global loss: 0.0423251218 || the best loss: 0.0050870073
# simulation: 36 || global loss: 0.0483963747 || the best loss: 0.0050870073
# simulation: 37 || global loss: 0.0451591116 || the best loss: 0.0050870073
# simulation: 38 || global loss: 0.0402773049 || the best loss: 0.0050870073
# simulation: 39 || global loss: 0.0241951452 || the best loss: 0.0050870073
# simulation: 40 || global loss: 0.0179532039 || the best loss: 0.0050870073
# simulation: 41 || global loss: 0.0066968951 || the best loss: 0.0050870073
# simulation: 42 || global loss: 0.0088841328 || the best loss: 0.0050870073
# simulation: 43 || global loss: 0.0362319006 || the best loss: 0.0050870073
# simulation: 44 || global loss: 0.0360383314 || the best loss: 0.0050870073
# simulation: 45 || global loss: 0.0313632940 || the best loss: 0.0050870073
# simulation: 46 || global loss: 0.0023537266 || the best loss: 0.0023537266
# simulation: 47 || global loss: 0.0194275912 || the best loss: 0.0023537266
# simulation: 48 || global loss: 0.0445932275 || the best loss: 0.0023537266
# simulation: 49 || global loss: 0.0017500606 || the best loss: 0.0017500606

# %%
# Save the simulation
np.save('result/param_history.npy', param_history)
np.save('result/loss_history.npy', loss_history)
np.save('result/the_best_loss_history.npy', the_best_loss_history)
np.save('result/the_best_param_history.npy', the_best_param_history)

f = open("result/sim.cfg", "w+")
f.writelines('num: {} # The number of flowers\n'.format(num))
f.writelines('n_sim: {} # The number of simulation loop\n'.format(n_sim))
f.writelines('n_itr: {} # The number of iteration for each simulation\n'.format(n_itr))
f.writelines('\n# The boundary of the initialization value\n')
f.writelines('r_b1: {}\n'.format(r_b1))
f.writelines('r_b2: {}\n'.format(r_b2))
f.writelines('r_b3: {}\n'.format(r_b3))
f.writelines('\n# The PSO hyperparameters\n')
f.writelines('alpha0: {}\n'.format(alpha0))
f.writelines('beta: {}\n'.format(beta))
f.writelines('gamma: {}\n'.format(gamma))
f.close()

# %% [markdown]
# # RESULT

# %%
# # Load the model
the_best_param_history = np.load('result/the_best_param_history.npy')
the_best_loss_history = np.load('result/the_best_loss_history.npy')

# %%
print('Minimum Cost: {}'.format(the_best_loss_history[-1]))
print('Parameters:')
print(the_best_param_history[-1])
# Out:
# Minimum Cost: 0.0017500605643751002
# Parameters:
# [ 0.72189092 -0.15585199  0.1817861 ]

# %%
plt.scatter(v, u, linewidth=0.05)
plt.xlabel(r'Steady-State Speed $(m/s)$')
plt.ylabel('Throttle')
plt.title('Throttle vs Steady-State Speed')
plt.savefig('img/throttle_vs_speed', dpi=600, transparent=True, bbox_inches='tight',)
plt.show()

# %%
plt.scatter(v, u, label='Actual', linewidth=0.05)
plt.plot(v, forward_propagation(v, the_best_param_history[-1]), label='Prediction', color='red', linewidth=2)
plt.xlabel(r'Speed $(m/s)$')
plt.ylabel('Throttle')
plt.title('Prediction of Steady-State Response')
plt.legend()
plt.savefig('img/throttle_vs_speed_pred', dpi=600, transparent=True, bbox_inches='tight')
plt.show()
# Out:
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
